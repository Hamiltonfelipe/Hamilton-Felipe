# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamiltonfelipe/Hamilton-Felipe/blob/main/Projeto%2BInicial%2B_%2BExtra%C3%A7%C3%A3o%2Bdas%2Bcota%C3%A7%C3%B5es%2Be%2Bindicadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python e PBI - Análise Gráfica e Fundamentalista de Ativos
#
#
# ---

# %% [markdown]
# ## Instalando as bibliotecas no ambiente do Colab

# %%
# !pip install fundamentus yfinance
# Out:
# Requirement already satisfied: fundamentus in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.50)
# Requirement already satisfied: requests>=2.25.1 in /usr/local/lib/python3.10/dist-packages (from fundamentus) (2.32.3)
# Requirement already satisfied: requests-cache>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from fundamentus) (1.2.1)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from fundamentus) (2.2.2)
# Requirement already satisfied: lxml>=4.6.2 in /usr/local/lib/python3.10/dist-packages (from fundamentus) (5.3.0)
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.10/dist-packages (from fundamentus) (0.9.0)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->fundamentus) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->fundamentus) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->fundamentus) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->fundamentus) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->fundamentus) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->fundamentus) (2024.12.14)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache>=0.5.2->fundamentus) (24.3.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache>=0.5.2->fundamentus) (24.1.2)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache>=0.5.2->fundamentus) (1.4.3)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache>=0.5.2->fundamentus) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache>=0.5.2->fundamentus) (4.12.2)

# %% [markdown]
# ## Dados de cotações da carteira hipotética

# %%
# Importando a biblioteca
import yfinance as yf

# %%
# Definindo a carteira de ações
carteira_yf = ['ABEV3.SA', 'B3SA3.SA', 'ELET3.SA', 'GGBR4.SA', 'ITSA4.SA',
               'PETR4.SA', 'RENT3.SA', 'SUZB3.SA', 'VALE3.SA', 'WEGE3.SA']

# %%
# Carregando os dados da carteira
dados= yf.download(carteira_yf, start='2022-08-01', end='2023-08-01')
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
dados.head(3)
# Out:
# Price       Adj Close                                                        \
# Ticker       ABEV3.SA   B3SA3.SA   ELET3.SA   GGBR4.SA  ITSA4.SA   PETR4.SA
# Date
# 2022-08-01  12.954397   9.965705  44.577351  15.262522  5.894953  16.169100
# 2022-08-02  13.025234   9.901528  44.922466  15.733229  5.950176  16.241112
# 2022-08-03  12.954397  10.231580  45.066257  15.094873  5.998496  16.250711
#
# Price                                                   ...    Volume  \
# Ticker       RENT3.SA   SUZB3.SA   VALE3.SA   WEGE3.SA  ...  ABEV3.SA
# Date                                                    ...
# 2022-08-01  52.656384  43.352535  55.528900  26.874165  ...  34565900
# 2022-08-02  52.905106  43.708706  57.298851  27.356129  ...  12515800
# 2022-08-03  54.554073  43.224678  55.072144  27.105511  ...  19576600
#
# Price                                                                  \
# Ticker      B3SA3.SA  ELET3.SA  GGBR4.SA  ITSA4.SA  PETR4.SA RENT3.SA
# Date
# 2022-08-01  26237600  12239200  16655058  25799552  81365100  6769429
# 2022-08-02  29130100   7477600  16078734  15750344  69147100  4870629
# 2022-08-03  29172900   8281500  30645468  25337732  65544500  4927295
#
# Price
# Ticker     SUZB3.SA  VALE3.SA WEGE3.SA
# Date
# 2022-08-01  7127600  38874000  8202200
# 2022-08-02  4379000  32636900  7214800
# 2022-08-03  4451900  31934600  6627100
#
# [3 rows x 60 columns]

# %%
# Passando os ativos para o multindex do df
cotacoes= dados.stack(level=1) # o metodo stack agrupa colunas em formado de linhas em uma unica coluna
cotacoes
# Out:
# <ipython-input-31-92cc6951d14d>:2: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cotacoes= dados.stack(level=1) # o metodo stack agrupa colunas em formado de linhas em uma unica coluna
# Price                Adj Close      Close       High        Low       Open  \
# Date       Ticker
# 2022-08-01 ABEV3.SA  12.954397  14.630000  14.890000  14.430000  14.860000
#            B3SA3.SA   9.965705  10.870000  11.120000  10.710000  11.020000
#            ELET3.SA  44.577351  46.500000  46.889999  45.660000  45.799999
#            GGBR4.SA  15.262522  18.785713  19.547619  18.650793  19.547619
#            ITSA4.SA   5.894953   7.012189   7.127143   6.938290   7.102510
# ...                        ...        ...        ...        ...        ...
# 2023-07-31 PETR4.SA  23.551945  31.110001  31.150000  30.299999  30.299999
#            RENT3.SA  63.632690  67.067726  67.506729  66.289497  66.888138
#            SUZB3.SA  45.487904  48.070000  48.610001  47.340000  47.389999
#            VALE3.SA  60.842945  69.160004  69.680000  67.839996  68.000000
#            WEGE3.SA  39.072895  39.919998  40.290001  39.810001  40.290001
#
# Price                  Volume
# Date       Ticker
# 2022-08-01 ABEV3.SA  34565900
#            B3SA3.SA  26237600
#            ELET3.SA  12239200
#            GGBR4.SA  16655058
#            ITSA4.SA  25799552
# ...                       ...
# 2023-07-31 PETR4.SA  91290800
#            RENT3.SA   5980447
#            SUZB3.SA   4602700
#            VALE3.SA  26065700
#            WEGE3.SA   7141800
#
# [2500 rows x 6 columns]

# %%
cotacoes_tr=cotacoes.reset_index()
cotacoes_tr=cotacoes_tr.rename(columns={'Ticker':'Ativo'})
cotacoes_tr.head()
# Out:
# Price       Date     Ativo  Adj Close      Close       High        Low  \
# 0     2022-08-01  ABEV3.SA  12.954397  14.630000  14.890000  14.430000
# 1     2022-08-01  B3SA3.SA   9.965705  10.870000  11.120000  10.710000
# 2     2022-08-01  ELET3.SA  44.577351  46.500000  46.889999  45.660000
# 3     2022-08-01  GGBR4.SA  15.262522  18.785713  19.547619  18.650793
# 4     2022-08-01  ITSA4.SA   5.894953   7.012189   7.127143   6.938290
#
# Price       Open    Volume
# 0      14.860000  34565900
# 1      11.020000  26237600
# 2      45.799999  12239200
# 3      19.547619  16655058
# 4       7.102510  25799552

# %%
# Organizando o df
cotacoes_c = cotacoes_tr[["Date", "Open", "High", "Low", "Close", "Ativo"]]
cotacoes_c.head(10)
# Out:
# Price       Date       Open       High        Low      Close     Ativo
# 0     2022-08-01  14.860000  14.890000  14.430000  14.630000  ABEV3.SA
# 1     2022-08-01  11.020000  11.120000  10.710000  10.870000  B3SA3.SA
# 2     2022-08-01  45.799999  46.889999  45.660000  46.500000  ELET3.SA
# 3     2022-08-01  19.547619  19.547619  18.650793  18.785713  GGBR4.SA
# 4     2022-08-01   7.102510   7.127143   6.938290   7.012189  ITSA4.SA
# 5     2022-08-01  34.000000  34.150002  33.220001  33.680000  PETR4.SA
# 6     2022-08-01  57.130951  57.608704  56.533764  56.892078  RENT3.SA
# 7     2022-08-01  48.360001  48.360001  46.950001  47.470001  SUZB3.SA
# 8     2022-08-01  68.940002  69.849998  67.930000  68.080002  VALE3.SA
# 9     2022-08-01  28.040001  28.680000  27.770000  27.879999  WEGE3.SA

# %%
cotacoes_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2500 non-null   datetime64[ns]
#  1   Open    2500 non-null   float64
#  2   High    2500 non-null   float64
#  3   Low     2500 non-null   float64
#  4   Close   2500 non-null   float64
#  5   Ativo   2500 non-null   object
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 117.3+ KB

# %% [markdown]
# ### Código completo das cotações da carteira

# %%
# Código completo da obtenção dos dados históricos das cotações da carteira de 01/08/2022 à 01/08/2023
# Importando a biblioteca
import yfinance as yf

# Definindo a carteira de ações
carteira_yf = ['ABEV3.SA', 'B3SA3.SA', 'ELET3.SA', 'GGBR4.SA', 'ITSA4.SA',
               'PETR4.SA', 'RENT3.SA', 'SUZB3.SA', 'VALE3.SA', 'WEGE3.SA']

# Carregando os dados da carteira
df = yf.download(carteira_yf, start="2022-08-01", end="2023-08-01")

# Passando os ativos para o multindex do df
cotacoes_yf = df.stack(level=1)

# Resetando os índices e renomenado a coluna dos ativos
cotacoes_yf = cotacoes_yf.reset_index().rename(columns={'Ticker': 'Ativo'})
cotacoes_yf
# Organizando o df
cotacoes = cotacoes_yf[["Date", "Open", "High", "Low", "Close", "Ativo"]]

del carteira_yf, df
# Out:
# [*********************100%***********************]  10 of 10 completed
# <ipython-input-35-c322016a7967>:13: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cotacoes_yf = df.stack(level=1)

# %% [markdown]
# ## Dados dos indicadores da carteira hipotética

# %%
# Importando as bibliotecas
import fundamentus
import pandas as pd

# %%
# Lendo um papel específico
weg= fundamentus.get_papel('WEGE3')
weg
# Out:
# /usr/local/lib/python3.10/dist-packages/fundamentus/detalhes.py:232: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables_html = pd.read_html(content.text, decimal=",", thousands='.')
#        Papel   Tipo       Empresa                    Setor  \
# WEGE3  WEGE3  ON N1  WEG SA ON N1  Máquinas e Equipamentos
#
#                              Subsetor Cotacao Data_ult_cot Min_52_sem  \
# WEGE3  Motores, Compressores e Outros   52.46   2025-01-03      31.79
#
#       Max_52_sem Vol_med_2m  ...  Ativo_Circulante   Div_Bruta  Div_Liquida  \
# WEGE3      58.48  360650000  ...       23752100000  3027030000  -3083980000
#
#         Patrim_Liq Receita_Liquida_12m    EBIT_12m Lucro_Liquido_12m  \
# WEGE3  19724500000         35725900000  8122710000        6093230000
#
#       Receita_Liquida_3m     EBIT_3m Lucro_Liquido_3m
# WEGE3         9856930000  2266470000       1578680000
#
# [1 rows x 48 columns]

# %%
# Definindo a carteira de ações
carteira_fund = ["ABEV3", "B3SA3", "ELET3", "GGBR4", "ITSA4",
                 "PETR4", "RENT3", "SUZB3", "VALE3", "WEGE3"]

# %%
# Criando um df com algumas infos da carteira
ind = pd.concat([fundamentus.get_papel(papel)[['Setor', 'Cotacao', 'Min_52_sem', 'Max_52_sem', 'Valor_de_mercado',
                                            'Nro_Acoes', 'Patrim_Liq','Receita_Liquida_12m','Receita_Liquida_3m',
                                            'Lucro_Liquido_12m', 'Lucro_Liquido_3m']] for papel in carteira_fund], )
ind.head(3)
# Out:
# /usr/local/lib/python3.10/dist-packages/fundamentus/detalhes.py:232: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables_html = pd.read_html(content.text, decimal=",", thousands='.')
# /usr/local/lib/python3.10/dist-packages/fundamentus/detalhes.py:232: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables_html = pd.read_html(content.text, decimal=",", thousands='.')
# /usr/local/lib/python3.10/dist-packages/fundamentus/detalhes.py:232: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables_html = pd.read_html(content.text, decimal=",", thousands='.')
# /usr/local/lib/python3.10/dist-packages/fundamentus/detalhes.py:232: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables_html = pd.read_html(content.text, decimal=",", thousands='.')
# /usr/local/lib/python3.10/dist-packages/fundamentus/detalhes.py:232: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables_html = pd.read_html(content.text, decimal=",", thousands='.')
# /usr/local/lib/python3.10/dist-packages/fundamentus/detalhes.py:232: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables_html = pd.read_html(content.text, decimal=",", thousands='.')
# /usr/local/lib/python3.10/dist-packages/fundamentus/detalhes.py:232: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables_html = pd.read_html(content.text, decimal=",", thousands='.')
# /usr/local/lib/python3.10/dist-packages/fundamentus/detalhes.py:232: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables_html = pd.read_html(content.text, decimal=",", thousands='.')
# /usr/local/lib/python3.10/dist-packages/fundamentus/detalhes.py:232: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables_html = pd.read_html(content.text, decimal=",", thousands='.')
# /usr/local/lib/python3.10/dist-packages/fundamentus/detalhes.py:232: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables_html = pd.read_html(content.text, decimal=",", thousands='.')
#                                Setor Cotacao Min_52_sem Max_52_sem  \
# ABEV3                        Bebidas   11.33      10.54      13.71
# B3SA3  Serviços Financeiros Diversos   10.10       9.10      13.86
# ELET3               Energia Elétrica   33.55      33.21      42.90
#
#        Valor_de_mercado    Nro_Acoes    Patrim_Liq Receita_Liquida_12m  \
# ABEV3      178534000000  15757700000   98140400000         82406500000
# B3SA3       54807700000   5426500000   19145200000         10398500000
# ELET3       77403200000   2307100000  121252000000         38078600000
#
#       Receita_Liquida_3m Lucro_Liquido_12m Lucro_Liquido_3m
# ABEV3        22096700000       13944500000       3460270000
# B3SA3         2711380000        4313670000       1204490000
# ELET3        11042900000       10155700000       7195280000

# %%
ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, ABEV3 to WEGE3
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Setor                10 non-null     object
#  1   Cotacao              10 non-null     object
#  2   Min_52_sem           10 non-null     object
#  3   Max_52_sem           10 non-null     object
#  4   Valor_de_mercado     10 non-null     int64
#  5   Nro_Acoes            10 non-null     object
#  6   Patrim_Liq           10 non-null     object
#  7   Receita_Liquida_12m  10 non-null     object
#  8   Receita_Liquida_3m   10 non-null     object
#  9   Lucro_Liquido_12m    10 non-null     object
#  10  Lucro_Liquido_3m     10 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 1.2+ KB

# %%
# Passando o ticker para uma coluna
ind= ind.reset_index()
ind.rename(columns={'index' : 'Ativo'}, inplace= True)

# Alterando colunas object para numeric
colunas = ['Cotacao', 'Min_52_sem', 'Max_52_sem', 'Valor_de_mercado', 'Nro_Acoes', 'Patrim_Liq',
           'Receita_Liquida_12m', 'Receita_Liquida_3m', 'Lucro_Liquido_12m', 'Lucro_Liquido_3m']
ind[colunas] = ind[colunas].apply(pd.to_numeric, errors='coerce', axis=1)
ind.head()
# Out:
#    Ativo                          Setor  Cotacao  Min_52_sem  Max_52_sem  \
# 0  ABEV3                        Bebidas    11.33       10.54       13.71
# 1  B3SA3  Serviços Financeiros Diversos    10.10        9.10       13.86
# 2  ELET3               Energia Elétrica    33.55       33.21       42.90
# 3  GGBR4        Siderurgia e Metalurgia    17.32       16.45       21.15
# 4  ITSA4     Intermediários Financeiros     8.53        8.53       10.59
#
#    Valor_de_mercado     Nro_Acoes    Patrim_Liq  Receita_Liquida_12m  \
# 0      1.785340e+11  1.575770e+10  9.814040e+10         8.240650e+10
# 1      5.480770e+10  5.426500e+09  1.914520e+10         1.039850e+10
# 2      7.740320e+10  2.307100e+09  1.212520e+11         3.807860e+10
# 3      3.600490e+10  2.078810e+09  5.529500e+10         6.491960e+10
# 4      9.250410e+10  1.084460e+10  8.646300e+10         8.119000e+09
#
#    Receita_Liquida_3m  Lucro_Liquido_12m  Lucro_Liquido_3m
# 0        2.209670e+10       1.394450e+10      3.460270e+09
# 1        2.711380e+09       4.313670e+09      1.204490e+09
# 2        1.104290e+10       1.015570e+10      7.195280e+09
# 3        1.737800e+10       4.828240e+09      1.347400e+09
# 4        2.240000e+09       1.404000e+10      3.819000e+09

# %%
ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ativo                10 non-null     object
#  1   Setor                10 non-null     object
#  2   Cotacao              10 non-null     float64
#  3   Min_52_sem           10 non-null     float64
#  4   Max_52_sem           10 non-null     float64
#  5   Valor_de_mercado     10 non-null     float64
#  6   Nro_Acoes            10 non-null     float64
#  7   Patrim_Liq           10 non-null     float64
#  8   Receita_Liquida_12m  10 non-null     float64
#  9   Receita_Liquida_3m   10 non-null     float64
#  10  Lucro_Liquido_12m    10 non-null     float64
#  11  Lucro_Liquido_3m     10 non-null     float64
# dtypes: float64(10), object(2)
# memory usage: 1.1+ KB

# %%
# Criando um novo df com alguns indicadores da carteira
n_ind= fundamentus.get_resultado_raw().reset_index()
n_ind= n_ind.query('papel in @carteira_fund')

n_ind = n_ind[['papel','P/L', 'Div.Yield','P/VP','ROE']].reset_index(drop=True)

n_ind.rename(columns={'papel': 'Ativo','Div.Yield':'DY'}, inplace= True)
n_ind.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/fundamentus/resultado.py:50: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(content.text, decimal=",", thousands='.')[0]
# Multiples  Ativo    P/L      DY  P/VP     ROE
# 0          ABEV3  12.80  0.0589  1.82  0.1421
# 1          B3SA3  12.71  0.0371  2.86  0.2253
# 2          ELET3   7.62  0.0378  0.64  0.0838
# 3          GGBR4   7.46  0.0459  0.65  0.0873
# 4          ITSA4   6.59  0.0743  1.07  0.1624

# %%
# Concatenando os dfs em um só com as infos e indicadores
indicadores= pd.merge(ind, n_ind, on='Ativo')
# Criando uma coluna para LPA (Lucro por Ação) e VPA (Valor Patrimonial por ação)
# para calcular a fórmula de Graham  Valor intrínseco de uma ação (VI = √22,5 x LPA x VPA)
indicadores['LPA']= (indicadores['Lucro_Liquido_12m'] / indicadores['Nro_Acoes']).round(2)
indicadores['VPA']= (indicadores['Patrim_Liq'] / indicadores['Nro_Acoes']).round(2)
indicadores
# Out:
#    Ativo                            Setor  Cotacao  Min_52_sem  Max_52_sem  \
# 0  ABEV3                          Bebidas    11.33       10.54       13.71
# 1  B3SA3    Serviços Financeiros Diversos    10.10        9.10       13.86
# 2  ELET3                 Energia Elétrica    33.55       33.21       42.90
# 3  GGBR4          Siderurgia e Metalurgia    17.32       16.45       21.15
# 4  ITSA4       Intermediários Financeiros     8.53        8.53       10.59
# 5  PETR4  Petróleo, Gás e Biocombustíveis    36.38       29.36       37.74
# 6  RENT3                         Diversos    32.28       29.93       60.80
# 7  SUZB3                  Madeira e Papel    62.68       45.39       64.87
# 8  VALE3                        Mineração    53.24       53.24       69.67
# 9  WEGE3          Máquinas e Equipamentos    52.46       31.79       58.48
#
#    Valor_de_mercado     Nro_Acoes    Patrim_Liq  Receita_Liquida_12m  \
# 0      1.785340e+11  1.575770e+10  9.814040e+10         8.240650e+10
# 1      5.480770e+10  5.426500e+09  1.914520e+10         1.039850e+10
# 2      7.740320e+10  2.307100e+09  1.212520e+11         3.807860e+10
# 3      3.600490e+10  2.078810e+09  5.529500e+10         6.491960e+10
# 4      9.250410e+10  1.084460e+10  8.646300e+10         8.119000e+09
# 5      4.745590e+11  1.304450e+10  3.936550e+11         5.038190e+11
# 6      3.494700e+10  1.082620e+09  2.563870e+10         3.532730e+10
# 7      7.923490e+10  1.264120e+09  4.147080e+10         4.359780e+10
# 8      2.416570e+11  4.539010e+09  2.085550e+11         2.111090e+11
# 9      2.201910e+11  4.197320e+09  1.972450e+10         3.572590e+10
#
#    Receita_Liquida_3m  Lucro_Liquido_12m  Lucro_Liquido_3m    P/L      DY  \
# 0        2.209670e+10       1.394450e+10      3.460270e+09  12.80  0.0589
# 1        2.711380e+09       4.313670e+09      1.204490e+09  12.71  0.0371
# 2        1.104290e+10       1.015570e+10      7.195280e+09   7.62  0.0378
# 3        1.737800e+10       4.828240e+09      1.347400e+09   7.46  0.0459
# 4        2.240000e+09       1.404000e+10      3.819000e+09   6.59  0.0743
# 5        1.295820e+11       8.469300e+10      3.255500e+10   5.60  0.2164
# 6        9.683370e+09       1.681320e+09      8.111780e+08  20.79  0.0488
# 7        1.227350e+10       4.181440e+09      3.224270e+09  18.95  0.0322
# 8        5.297800e+10       4.825100e+10      1.338600e+10   5.01  0.1005
# 9        9.856930e+09       6.093230e+09      1.578680e+09  36.14  0.0144
#
#     P/VP     ROE    LPA    VPA
# 0   1.82  0.1421   0.88   6.23
# 1   2.86  0.2253   0.79   3.53
# 2   0.64  0.0838   4.40  52.56
# 3   0.65  0.0873   2.32  26.60
# 4   1.07  0.1624   1.29   7.97
# 5   1.21  0.2151   6.49  30.18
# 6   1.36  0.0656   1.55  23.68
# 7   1.91  0.1008   3.31  32.81
# 8   1.16  0.2314  10.63  45.95
# 9  11.16  0.3089   1.45   4.70
